# %% [markdown]
# # Logging

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2026-01-16 08:47:00.826351

# %%
import logging

# %%
# creating a file to store the logging data which i used in another cell
logging.basicConfig(filename="logs2.txt", filemode="w", level=logging.DEBUG, format=' %(asctime)s - %(name)s - %(levelname)s - %(message)s')
# logging.basicConfig(filename="logs2.txt", filemode="w", level=logging.DEBUG)
# logging.basicConfig(filename="logs2.txt", filemode="w", level=logging.INFO)
# logging.basicConfig(filename="logs2.txt", filemode="w")

# %%
# example of logging messages
logging.debug("this is a debug message")
logging.info("this is a info message")
logging.warning("this is a warning message")
logging.error("this is a error message")
logging.critical("this is a critical message")

# %%
inputName= input("enter a number")

# %%
try:
    number= int(input)
except Exception as e:
    logging.error(e)
    logging.info(inputName)
    logging.debug("Number should be defaulted")
