# %%
import scipy.stats as stat
import numpy as np

# %%
# No of hours student study in a weekly basis daily
# monday,tuesday,Wednesday,thursday,Friday,Saturday,sunday
expected_data=[8,6,7,9,6,9,7]
observed_data=[7,8,6,9,9,6,7]

# %%
sum(expected_data),sum(observed_data)
# this sum must be equal, expected or observed: the whole should be same
# Out:
# (52, 52)

# %%
## Chi-Square Goodness Of Fit Test
chisquare_test_statistic,p_value=stat.chisquare(observed_data,expected_data)

chisquare_test_statistic,p_value
# Out:
# (np.float64(3.4345238095238093), np.float64(0.7526596580922865))

# %%
## find the critical value
significane_value=0.05
dof=len(expected_data)-1
print(dof)
critical_value=stat.chi2.ppf(1-significane_value,dof) # ppf funtion
