# %% [markdown]
# # Calculating Mean

# %%
a= [112,14,13,16,17,35,45,23,22,12]
import numpy as np
print(int(np.mean(a)))
# Out:
# 30

# %% [markdown]
# # importing datasaet from seaborn

# %%
import seaborn as sns
dataframe=sns.load_dataset('tips')
dataframe.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # finding the average of total bill

# %%
np.mean(dataframe['total_bill'])
# Out:
# np.float64(19.78594262295082)

# %% [markdown]
# # Calculating Median

# %%
# Calculating Median
a= [112,14,13,16,17,35,45,23,22,12]
import numpy as np
print(int(np.median(a)))
# Out:
# 19

# %% [markdown]
# # calculating mean on outlayer

# %%
a= [112,14,13,16,17,35,45,23,22,12,12,220]
import numpy as np
print(int(np.mean(a)))
# Out:
# 45

# %% [markdown]
# # calculating median on outlayer

# %%
print(int(np.median(a)))
# Out:
# 22

# %% [markdown]
# # calculating mode

# %%
from scipy import stats

# %%
stats.mode(a)
# Out:
# ModeResult(mode=np.int64(12), count=np.int64(2))
